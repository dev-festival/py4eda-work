# %% [markdown]
# **Q1**
# You have a dataset tracking student test scores that looks like this:
# ```
# student_id | test1_score | test2_score | test3_score
# 101        | 85          | 90          | 88
# 102        | 92          | 87          | 91
# ```
# Is this tidy data? If not, what principle does it violate and how would you describe the tidy version?

# %% [markdown]
# *Q1* - I don't think this is tidy data. It is pivoted out by test score. To be more tidy it would have a student_id column (as is), then a test_name for each test1, test2, test3 and a third column for score.

# %% [markdown]
# **Q2** You want to create a scatterplot showing the relationship between temperature and ice cream sales, with different colors for weekday vs weekend, and you want to add a trend line.
# Map the following to the 5 Grammar of Graphics components:
#
# * Data layer
# * Aesthetics layer
# * Geoms layer
# * Stats layer
# * Facets layer (if applicable)

# %% [markdown]
# *Q2* Data layer is the the actual dataframe that contains the temperature and sales. Aesthetics  layer is the x / y axis selections that are mapped to variables. the Geoms layer are the data points layed up on the plot. Stats layers is going to be the trend line. Not sure about the Facets

# %% [markdown]
# **Q3** You just modified analysis.py in your project. Walk through the Git commands you'd use to:
#
# 1) Check what files have changed
# 2) Prepare the file for commit
# 3) Save it to your local repository with message "Add correlation analysis"
# 4) Upload it to GitHub
#
# What's happening at each stage of Git's three-stage model?

# %% [markdown]
# *Q3* -
# 1) git status - see whats modified - nothing stages (maybe)
# 2) git add analysis.py - stage the file
#    git status - confirm staging
# 3) git commit  -m "add: correlation analysis" - commit changes
# 4) git push - backup to cloud

# %% [markdown]
# **ANSWERS**
#
# *Q1* - I don't think this is tidy data. It is pivoted out by test score. To be more tidy it would have a student_id column (as is), then a test_name for each test1, test2, test3 and a third column for score.
#
# *Q2* Data layer is the the actual dataframe that contains the temperature and sales. Aesthetics  layer is the x / y axis selections that are mapped to variables. the Geoms layer are the data points layed up on the plot. Stats layers is going to be the trend line. Not sure about the Facets
#
#
# *Q3* -
# 1) git status - see whats modified - nothing stages (maybe)
# 2) git add analysis.py - stage the file
#    git status - confirm staging
# 3) git commit  -m "add: correlation analysis" - commit changes
# 4) git push - backup to cloud

# %% [markdown]
# **Q4** You're analyzing a dataset of 500 employees with these variables:
#
# * salary (continuous numeric)
# * department (categorical: Sales, Engineering, HR, Marketing)
# * years_experience (continuous numeric)
# * performance_rating (categorical ordered: Low, Medium, High, Excellent)
#
# For each scenario, what plot type would you choose?
# 1) Show the distribution of salaries across all employees
# 2) Compare average salary across the 4 departments
# 3) Examine if there's a relationship between years of experience and salary

# %% [markdown]
# *Q4*
# 1) Histogram of standard deviation of salaries with
# 2) Bar chart of average salaries
# 3) Scatter plot of years of experience and salary

# %% [markdown]
# **Q5** Match each Seaborn function to its family (relational, distributional, or categorical):
#
# 1) sns.scatterplot()
# 2) sns.histplot()
# 3) sns.boxplot()
# 4) sns.lineplot()
# 5) sns.violinplot()
# 6) sns.kdeplot()
#
# Bonus: Which function would you use to quickly explore relationships between ALL numeric variables in a dataset?

# %% [markdown]
# *Q5*
# 1) relational
# 2) distributional
# 3) distributional
# 4) categorical
# 5) distributional
# 6) ** not sure
#
# Bonus: I think this is a duo plot from R, but not sure how to call for sns.

# %% [markdown]
# **Q6** Your data science project has these files:
# ```
# project/
# ├── analysis.py
# ├── data_raw.csv (100MB)
# ├── data_cleaned.csv (5MB, created by your script)
# ├── results.png
# ├── __pycache__/
# ├── .ipynb_checkpoints/
# ├── config.py (contains API keys)
# └── README.md
# ```
# Which files/folders should be in your .gitignore and why? Group your reasoning by category (e.g., "too large", "regeneratable", "sensitive", etc.)

# %% [markdown]
# *Q6* - .gitignore should include __pycache__ (too large), .ipynb_checkpoints (regenerateable), config.py (sensitive) ... the data file, even though it is 100MB might be too large but it might also be needed to host for sharing purposes so I'd leave it off the gitignor... at least originally.

# %% [markdown]
# **ANSWERS**
#
# *Q4*
# 1) Histogram of standard deviation of salaries with
# 2) Bar chart of average salaries
# 3) Scatter plot of years of experience and salary
#
# *Q5*
# 1) relational
# 2) distributional
# 3) distributional
# 4) categorical
# 5) distributional
# 6) ** not sure
#
# Bonus: I think this is a duo plot from R, but not sure how to call for sns.
#
# *Q6* - .gitignore should include __pycache__ (too large), .ipynb_checkpoints (regenerateable), config.py (sensitive) ... the data file, even though it is 100MB might be too large but it might also be needed to host for sharing purposes so I'd leave it off the gitignor... at least originally.

# %% [markdown]
# **Q7**
# You have a DataFrame df with columns: date, temperature, humidity, city.
# For each task, would you use Pandas .plot() or Seaborn, and why?
# 1) Quick check: "Is my temperature data reasonable? Any obvious outliers?"
# 2) Presentation-ready plot: Compare temperature distributions across 5 cities with violin plots, custom colors, and labeled axes
# 3) Exploratory: View time series of temperature over the year

# %% [markdown]
# *Q7* -
# 1) quick check - pandas plot (quick and dirty syntax)
# 2) presentation ready - seaborn (can make clean and pretty)
# 3) explorator - seaborn

# %% [markdown]
# **Q8**
# You're analyzing survey data with an education_level column containing: "High School", "Bachelor's", "Master's", "PhD", "Associate's"
# 1) Is this an ordered or unordered categorical variable?
# 2) You create a Seaborn countplot with sns.countplot(data=df, x='education_level'). By default, how will Seaborn order these categories on the x-axis?
# 3) How would you force them to appear in the logical educational progression order?

# %% [markdown]
# *Q8* -
# 1) This is an ordered categorical variable, for level of education.
# 2) Seaborn will order these alphabetically by default
# 3) yoou can set the order, although i'm not sure how to explicitly

# %% [markdown]
# **Q9** Explain the difference between a Figure and Axes object in Matplotlib.
# Then, what does this code create?
# ```python
# pythonfig, ax = plt.subplots(2, 3, figsize=(15, 10))
# ```
# How would you access the Axes in the top-right corner?

# %% [markdown]
# *Q9* I'm not sure on this one.

# %% [markdown]
# **ANSWERS**
#
# *Q7* -
# 1) quick check - pandas plot (quick and dirty syntax)
# 2) presentation ready - seaborn (can make clean and pretty)
# 3) explorator - seaborn
#
# *Q8* -
# 1) This is an ordered categorical variable, for level of education.
# 2) Seaborn will order these alphabetically by default
# 3) yoou can set the order, although i'm not sure how to explicitly
#
# *Q9* I'm not sure on this one.
